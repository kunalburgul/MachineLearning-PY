# %% [markdown]
# # TensorFlow Classification

# %%
import pandas as pd

diabetes = pd.read_csv('pima-indians-diabetes.csv')
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0y/41vh8h4d1wv2yccr48slhmgc0000gn/T/tmpa4st1fko
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/0y/41vh8h4d1wv2yccr48slhmgc0000gn/T/tmpa4st1fko', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a496810b8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From /Users/pymacbit/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /Users/pymacbit/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Users/pymacbit/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Users/pymacbit/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:305: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /Users/pymacbit/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /Users/pymacbit/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/ops/embedding_ops.py:802: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/pymacbit/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/canned/linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /Users/pymacbit/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/training/monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/0y/41vh8h4d1wv2yccr48slhmgc0000gn/T/tmpa4st1fko/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 56.6886
# INFO:tensorflow:loss = 6.4489517, step = 101 (1.770 sec)
# INFO:tensorflow:global_step/sec: 205.429
# INFO:tensorflow:loss = 5.6523204, step = 201 (0.482 sec)
# INFO:tensorflow:global_step/sec: 216.657
# INFO:tensorflow:loss = 6.2057614, step = 301 (0.462 sec)
# INFO:tensorflow:global_step/sec: 217.249
# INFO:tensorflow:loss = 4.003536, step = 401 (0.460 sec)
# INFO:tensorflow:global_step/sec: 211.913
# INFO:tensorflow:loss = 5.2952747, step = 501 (0.474 sec)
# INFO:tensorflow:global_step/sec: 239.273
# INFO:tensorflow:loss = 5.244952, step = 601 (0.416 sec)
# INFO:tensorflow:global_step/sec: 235.24
# INFO:tensorflow:loss = 5.3475575, step = 701 (0.425 sec)
# INFO:tensorflow:global_step/sec: 215.852
# INFO:tensorflow:loss = 5.0237317, step = 801 (0.463 sec)
# INFO:tensorflow:global_step/sec: 193.736
# INFO:tensorflow:loss = 6.652052, step = 901 (0.516 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/0y/41vh8h4d1wv2yccr48slhmgc0000gn/T/tmpa4st1fko/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.2762303.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Users/pymacbit/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/ops/metrics_impl.py:2026: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-16T11:39:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/0y/41vh8h4d1wv2yccr48slhmgc0000gn/T/tmpa4st1fko/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-16-11:39:14
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.71259844, accuracy_baseline = 0.65748036, auc = 0.7851538, auc_precision_recall = 0.62752116, average_loss = 0.54383963, global_step = 1000, label/mean = 0.34251967, loss = 5.312895, precision = 0.57608694, prediction/mean = 0.41274804, recall = 0.6091954
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /var/folders/0y/41vh8h4d1wv2yccr48slhmgc0000gn/T/tmpa4st1fko/model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.71259844,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7851538,
#  'auc_precision_recall': 0.62752116,
#  'average_loss': 0.54383963,
#  'label/mean': 0.34251967,
#  'loss': 5.312895,
#  'precision': 0.57608694,
#  'prediction/mean': 0.41274804,
#  'recall': 0.6091954,
#  'global_step': 1000}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/0y/41vh8h4d1wv2yccr48slhmgc0000gn/T/tmpa4st1fko/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.31869817], dtype=float32),
#   'logistic': array([0.57900697], dtype=float32),
#   'probabilities': array([0.42099306, 0.57900697], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7425213], dtype=float32),
#   'logistic': array([0.677547], dtype=float32),
#   'probabilities': array([0.32245305, 0.6775469 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.1209904], dtype=float32),
#   'logistic': array([0.46978924], dtype=float32),
#   'probabilities': array([0.5302108 , 0.46978924], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5998714], dtype=float32),
#   'logistic': array([0.35437316], dtype=float32),
#   'probabilities': array([0.6456269, 0.3543731], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5994961], dtype=float32),
#   'logistic': array([0.16805202], dtype=float32),
#   'probabilities': array([0.83194804, 0.16805205], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1170886], dtype=float32),
#   'logistic': array([0.75344825], dtype=float32),
#   'probabilities': array([0.2465517, 0.7534483], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5856478], dtype=float32),
#   'logistic': array([0.64236593], dtype=float32),
#   'probabilities': array([0.357634  , 0.64236593], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.351843], dtype=float32),
#   'logistic': array([0.41293558], dtype=float32),
#   'probabilities': array([0.58706445, 0.41293553], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9712344], dtype=float32),
#   'logistic': array([0.27463454], dtype=float32),
#   'probabilities': array([0.7253654, 0.2746345], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.92365724], dtype=float32),
#   'logistic': array([0.28421327], dtype=float32),
#   'probabilities': array([0.7157867 , 0.28421327], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7266297], dtype=float32),
#   'logistic': array([0.15101919], dtype=float32),
#   'probabilities': array([0.84898084, 0.15101917], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5668173], dtype=float32),
#   'logistic': array([0.17267057], dtype=float32),
#   'probabilities': array([0.82732946, 0.17267056], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5571271], dtype=float32),
#   'logistic': array([0.36421245], dtype=float32),
#   'probabilities': array([0.63578755, 0.3642124 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.62944984], dtype=float32),
#   'logistic': array([0.6523647], dtype=float32),
#   'probabilities': array([0.3476353, 0.6523647], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.424359], dtype=float32),
#   'logistic': array([0.19397914], dtype=float32),
#   'probabilities': array([0.8060209 , 0.19397914], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4761725], dtype=float32),
#   'logistic': array([0.38315636], dtype=float32),
#   'probabilities': array([0.61684364, 0.3831563 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.28714663], dtype=float32),
#   'logistic': array([0.42870256], dtype=float32),
#   'probabilities': array([0.5712974 , 0.42870256], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7383494], dtype=float32),
#   'logistic': array([0.14952269], dtype=float32),
#   'probabilities': array([0.85047734, 0.14952269], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2831974], dtype=float32),
#   'logistic': array([0.42967004], dtype=float32),
#   'probabilities': array([0.57032996, 0.42967013], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.681972], dtype=float32),
#   'logistic': array([0.15683453], dtype=float32),
#   'probabilities': array([0.8431655 , 0.15683453], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1328146], dtype=float32),
#   'logistic': array([0.24364206], dtype=float32),
#   'probabilities': array([0.756358  , 0.24364203], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6684249], dtype=float32),
#   'logistic': array([0.33884963], dtype=float32),
#   'probabilities': array([0.6611504 , 0.33884963], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.92912936], dtype=float32),
#   'logistic': array([0.7168986], dtype=float32),
#   'probabilities': array([0.28310138, 0.7168986 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1420304], dtype=float32),
#   'logistic': array([0.24194777], dtype=float32),
#   'probabilities': array([0.75805223, 0.24194776], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3172319], dtype=float32),
#   'logistic': array([0.21127921], dtype=float32),
#   'probabilities': array([0.78872085, 0.21127918], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.4778647], dtype=float32),
#   'logistic': array([0.8142499], dtype=float32),
#   'probabilities': array([0.18575014, 0.8142499 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3593147], dtype=float32),
#   'logistic': array([0.2043517], dtype=float32),
#   'probabilities': array([0.79564834, 0.20435172], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5651237], dtype=float32),
#   'logistic': array([0.36236277], dtype=float32),
#   'probabilities': array([0.63763726, 0.36236277], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0381222], dtype=float32),
#   'logistic': array([0.11525808], dtype=float32),
#   'probabilities': array([0.88474196, 0.11525808], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.66478264], dtype=float32),
#   'logistic': array([0.66033393], dtype=float32),
#   'probabilities': array([0.3396661 , 0.66033393], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.0232363], dtype=float32),
#   'logistic': array([0.9536129], dtype=float32),
#   'probabilities': array([0.0463871 , 0.95361286], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.15879095], dtype=float32),
#   'logistic': array([0.46038547], dtype=float32),
#   'probabilities': array([0.53961456, 0.46038544], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6529523], dtype=float32),
#   'logistic': array([0.34232455], dtype=float32),
#   'probabilities': array([0.65767545, 0.34232455], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5253991], dtype=float32),
#   'logistic': array([0.6284094], dtype=float32),
#   'probabilities': array([0.37159058, 0.6284094 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9271952], dtype=float32),
#   'logistic': array([0.2834941], dtype=float32),
#   'probabilities': array([0.7165059 , 0.28349409], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.16790664], dtype=float32),
#   'logistic': array([0.4581217], dtype=float32),
#   'probabilities': array([0.54187834, 0.45812166], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.29423404], dtype=float32),
#   'logistic': array([0.5730324], dtype=float32),
#   'probabilities': array([0.42696762, 0.5730323 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.80216813], dtype=float32),
#   'logistic': array([0.69043803], dtype=float32),
#   'probabilities': array([0.3095619, 0.6904381], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.4058814], dtype=float32),
#   'logistic': array([0.8031155], dtype=float32),
#   'probabilities': array([0.19688448, 0.80311555], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.50532645], dtype=float32),
#   'logistic': array([0.37628976], dtype=float32),
#   'probabilities': array([0.6237103 , 0.37628973], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3213551], dtype=float32),
#   'logistic': array([0.21059296], dtype=float32),
#   'probabilities': array([0.7894071 , 0.21059293], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4240328], dtype=float32),
#   'logistic': array([0.60444784], dtype=float32),
#   'probabilities': array([0.39555213, 0.6044479 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4948211], dtype=float32),
#   'logistic': array([0.18319917], dtype=float32),
#   'probabilities': array([0.81680083, 0.1831992 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.31325245], dtype=float32),
#   'logistic': array([0.5776789], dtype=float32),
#   'probabilities': array([0.42232105, 0.5776789 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6066043], dtype=float32),
#   'logistic': array([0.16706058], dtype=float32),
#   'probabilities': array([0.83293945, 0.16706058], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0789413], dtype=float32),
#   'logistic': array([0.11116052], dtype=float32),
#   'probabilities': array([0.8888395 , 0.11116052], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6578803], dtype=float32),
#   'logistic': array([0.65878403], dtype=float32),
#   'probabilities': array([0.34121594, 0.6587841 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3240546], dtype=float32),
#   'logistic': array([0.21014452], dtype=float32),
#   'probabilities': array([0.78985554, 0.2101445 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1679536], dtype=float32),
#   'logistic': array([0.23722507], dtype=float32),
#   'probabilities': array([0.76277494, 0.23722506], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9462755], dtype=float32),
#   'logistic': array([0.12496005], dtype=float32),
#   'probabilities': array([0.87504   , 0.12496004], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4516374], dtype=float32),
#   'logistic': array([0.18974969], dtype=float32),
#   'probabilities': array([0.81025034, 0.1897497 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8677952], dtype=float32),
#   'logistic': array([0.2957133], dtype=float32),
#   'probabilities': array([0.70428675, 0.29571325], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.95846814], dtype=float32),
#   'logistic': array([0.27718502], dtype=float32),
#   'probabilities': array([0.722815  , 0.27718502], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.24232507], dtype=float32),
#   'logistic': array([0.43971348], dtype=float32),
#   'probabilities': array([0.5602865 , 0.43971342], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6608789], dtype=float32),
#   'logistic': array([0.15964404], dtype=float32),
#   'probabilities': array([0.840356  , 0.15964405], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1356919], dtype=float32),
#   'logistic': array([0.2431122], dtype=float32),
#   'probabilities': array([0.75688785, 0.24311222], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.100542], dtype=float32),
#   'logistic': array([0.24963838], dtype=float32),
#   'probabilities': array([0.7503616 , 0.24963835], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1652161], dtype=float32),
#   'logistic': array([0.23772076], dtype=float32),
#   'probabilities': array([0.76227933, 0.23772077], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2905227], dtype=float32),
#   'logistic': array([0.57212406], dtype=float32),
#   'probabilities': array([0.42787594, 0.57212406], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.500707], dtype=float32),
#   'logistic': array([0.18232009], dtype=float32),
#   'probabilities': array([0.8176799 , 0.18232007], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0414747], dtype=float32),
#   'logistic': array([0.26086557], dtype=float32),
#   'probabilities': array([0.7391345 , 0.26086554], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9714291], dtype=float32),
#   'logistic': array([0.72540426], dtype=float32),
#   'probabilities': array([0.27459577, 0.72540426], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8360586], dtype=float32),
#   'logistic': array([0.69763446], dtype=float32),
#   'probabilities': array([0.3023655 , 0.69763446], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.32504272], dtype=float32),
#   'logistic': array([0.5805527], dtype=float32),
#   'probabilities': array([0.4194473, 0.5805527], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4671551], dtype=float32),
#   'logistic': array([0.38528982], dtype=float32),
#   'probabilities': array([0.6147102 , 0.38528982], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.25570023], dtype=float32),
#   'logistic': array([0.563579], dtype=float32),
#   'probabilities': array([0.43642098, 0.563579  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3340102], dtype=float32),
#   'logistic': array([0.20849678], dtype=float32),
#   'probabilities': array([0.79150325, 0.2084968 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2182972], dtype=float32),
#   'logistic': array([0.22823626], dtype=float32),
#   'probabilities': array([0.7717638 , 0.22823623], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5652455], dtype=float32),
#   'logistic': array([0.17289524], dtype=float32),
#   'probabilities': array([0.8271048 , 0.17289522], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6433284], dtype=float32),
#   'logistic': array([0.16201268], dtype=float32),
#   'probabilities': array([0.8379873 , 0.16201267], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6735803], dtype=float32),
#   'logistic': array([0.66230434], dtype=float32),
#   'probabilities': array([0.33769563, 0.6623044 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9986527], dtype=float32),
#   'logistic': array([0.2692064], dtype=float32),
#   'probabilities': array([0.7307936 , 0.26920643], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.06959331], dtype=float32),
#   'logistic': array([0.4826087], dtype=float32),
#   'probabilities': array([0.5173913, 0.4826087], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.62863684], dtype=float32),
#   'logistic': array([0.6521803], dtype=float32),
#   'probabilities': array([0.34781966, 0.65218025], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.82185674], dtype=float32),
#   'logistic': array([0.30536968], dtype=float32),
#   'probabilities': array([0.6946303 , 0.30536965], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8198252], dtype=float32),
#   'logistic': array([0.6941992], dtype=float32),
#   'probabilities': array([0.30580074, 0.6941992 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.800914], dtype=float32),
#   'logistic': array([0.14173982], dtype=float32),
#   'probabilities': array([0.85826015, 0.14173983], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5617585], dtype=float32),
#   'logistic': array([0.6368593], dtype=float32),
#   'probabilities': array([0.36314064, 0.63685936], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7578695], dtype=float32),
#   'logistic': array([0.14705737], dtype=float32),
#   'probabilities': array([0.85294265, 0.14705737], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5020783], dtype=float32),
#   'logistic': array([0.62294763], dtype=float32),
#   'probabilities': array([0.37705234, 0.62294763], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.44768596], dtype=float32),
#   'logistic': array([0.38991112], dtype=float32),
#   'probabilities': array([0.6100889 , 0.38991106], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4443147], dtype=float32),
#   'logistic': array([0.19087806], dtype=float32),
#   'probabilities': array([0.80912197, 0.19087808], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5690559], dtype=float32),
#   'logistic': array([0.6385453], dtype=float32),
#   'probabilities': array([0.36145467, 0.63854533], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5653316], dtype=float32),
#   'logistic': array([0.63768524], dtype=float32),
#   'probabilities': array([0.3623147 , 0.63768524], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.47646117], dtype=float32),
#   'logistic': array([0.6169119], dtype=float32),
#   'probabilities': array([0.38308808, 0.6169119 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.425262], dtype=float32),
#   'logistic': array([0.19383797], dtype=float32),
#   'probabilities': array([0.806162  , 0.19383799], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.39771825], dtype=float32),
#   'logistic': array([0.40186068], dtype=float32),
#   'probabilities': array([0.59813935, 0.40186068], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5165961], dtype=float32),
#   'logistic': array([0.17996332], dtype=float32),
#   'probabilities': array([0.8200367 , 0.17996329], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2092366], dtype=float32),
#   'logistic': array([0.7701639], dtype=float32),
#   'probabilities': array([0.22983614, 0.77016395], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.7886512], dtype=float32),
#   'logistic': array([0.8567618], dtype=float32),
#   'probabilities': array([0.14323816, 0.8567618 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.76868486], dtype=float32),
#   'logistic': array([0.6832363], dtype=float32),
#   'probabilities': array([0.31676364, 0.6832363 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1725053], dtype=float32),
#   'logistic': array([0.23640245], dtype=float32),
#   'probabilities': array([0.7635976 , 0.23640242], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.04291165], dtype=float32),
#   'logistic': array([0.48927373], dtype=float32),
#   'probabilities': array([0.5107263 , 0.48927373], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3072728], dtype=float32),
#   'logistic': array([0.42378056], dtype=float32),
#   'probabilities': array([0.57621944, 0.42378056], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.11892462], dtype=float32),
#   'logistic': array([0.52969617], dtype=float32),
#   'probabilities': array([0.47030377, 0.52969617], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.41707337], dtype=float32),
#   'logistic': array([0.3972173], dtype=float32),
#   'probabilities': array([0.6027827 , 0.39721727], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.08390617], dtype=float32),
#   'logistic': array([0.52096426], dtype=float32),
#   'probabilities': array([0.47903574, 0.52096426], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4801646], dtype=float32),
#   'logistic': array([0.18540254], dtype=float32),
#   'probabilities': array([0.8145975 , 0.18540254], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.53649783], dtype=float32),
#   'logistic': array([0.63099736], dtype=float32),
#   'probabilities': array([0.3690026 , 0.63099736], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6034721], dtype=float32),
#   'logistic': array([0.6464503], dtype=float32),
#   'probabilities': array([0.35354975, 0.6464503 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0156012], dtype=float32),
#   'logistic': array([0.2658851], dtype=float32),
#   'probabilities': array([0.7341149 , 0.26588514], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.351769], dtype=float32),
#   'logistic': array([0.2055813], dtype=float32),
#   'probabilities': array([0.7944187 , 0.20558132], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3583069], dtype=float32),
#   'logistic': array([0.20451564], dtype=float32),
#   'probabilities': array([0.7954844, 0.2045156], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7873132], dtype=float32),
#   'logistic': array([0.31274587], dtype=float32),
#   'probabilities': array([0.68725413, 0.31274587], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.27427042], dtype=float32),
#   'logistic': array([0.43185902], dtype=float32),
#   'probabilities': array([0.568141  , 0.43185902], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6293638], dtype=float32),
#   'logistic': array([0.16391754], dtype=float32),
#   'probabilities': array([0.83608246, 0.16391753], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5115916], dtype=float32),
#   'logistic': array([0.3748205], dtype=float32),
#   'probabilities': array([0.6251795 , 0.37482047], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.90938985], dtype=float32),
#   'logistic': array([0.28712472], dtype=float32),
#   'probabilities': array([0.7128753, 0.2871247], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.03244], dtype=float32),
#   'logistic': array([0.1158388], dtype=float32),
#   'probabilities': array([0.8841613, 0.1158388], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7905331], dtype=float32),
#   'logistic': array([0.14300738], dtype=float32),
#   'probabilities': array([0.85699266, 0.14300738], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3305788], dtype=float32),
#   'logistic': array([0.79093635], dtype=float32),
#   'probabilities': array([0.20906362, 0.79093635], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3845114], dtype=float32),
#   'logistic': array([0.20028543], dtype=float32),
#   'probabilities': array([0.79971457, 0.20028542], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6985557], dtype=float32),
#   'logistic': array([0.15465397], dtype=float32),
#   'probabilities': array([0.845346  , 0.15465398], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6310596], dtype=float32),
#   'logistic': array([0.16368526], dtype=float32),
#   'probabilities': array([0.83631474, 0.16368523], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2983111], dtype=float32),
#   'logistic': array([0.57402956], dtype=float32),
#   'probabilities': array([0.4259704 , 0.57402956], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.11803532], dtype=float32),
#   'logistic': array([0.5294746], dtype=float32),
#   'probabilities': array([0.47052538, 0.5294747 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0001317], dtype=float32),
#   'logistic': array([0.26891553], dtype=float32),
#   'probabilities': array([0.7310844 , 0.26891553], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.04115325], dtype=float32),
#   'logistic': array([0.48971313], dtype=float32),
#   'probabilities': array([0.51028687, 0.48971316], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2890525], dtype=float32),
#   'logistic': array([0.21601324], dtype=float32),
#   'probabilities': array([0.7839868 , 0.21601321], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0471272], dtype=float32),
#   'logistic': array([0.25977713], dtype=float32),
#   'probabilities': array([0.7402229 , 0.25977713], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.09201598], dtype=float32),
#   'logistic': array([0.5229878], dtype=float32),
#   'probabilities': array([0.4770122, 0.5229878], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.20367098], dtype=float32),
#   'logistic': array([0.55074245], dtype=float32),
#   'probabilities': array([0.44925752, 0.5507425 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5976009], dtype=float32),
#   'logistic': array([0.16831717], dtype=float32),
#   'probabilities': array([0.83168286, 0.16831717], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.13737273], dtype=float32),
#   'logistic': array([0.46571073], dtype=float32),
#   'probabilities': array([0.5342893, 0.4657107], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.054074], dtype=float32),
#   'logistic': array([0.74155647], dtype=float32),
#   'probabilities': array([0.2584435, 0.7415564], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.48317003], dtype=float32),
#   'logistic': array([0.6184961], dtype=float32),
#   'probabilities': array([0.3815038, 0.6184961], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.14846551], dtype=float32),
#   'logistic': array([0.46295166], dtype=float32),
#   'probabilities': array([0.5370484 , 0.46295163], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.48213625], dtype=float32),
#   'logistic': array([0.61825216], dtype=float32),
#   'probabilities': array([0.38174775, 0.61825216], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9733555], dtype=float32),
#   'logistic': array([0.2742122], dtype=float32),
#   'probabilities': array([0.72578776, 0.27421218], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2008669], dtype=float32),
#   'logistic': array([0.23132102], dtype=float32),
#   'probabilities': array([0.768679, 0.231321], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6837275], dtype=float32),
#   'logistic': array([0.15660253], dtype=float32),
#   'probabilities': array([0.8433975 , 0.15660253], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8644935], dtype=float32),
#   'logistic': array([0.2964014], dtype=float32),
#   'probabilities': array([0.7035986 , 0.29640135], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.1619296], dtype=float32),
#   'logistic': array([0.5403942], dtype=float32),
#   'probabilities': array([0.45960578, 0.5403942 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9643359], dtype=float32),
#   'logistic': array([0.72398907], dtype=float32),
#   'probabilities': array([0.27601093, 0.72398907], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0008054], dtype=float32),
#   'logistic': array([0.2687831], dtype=float32),
#   'probabilities': array([0.73121685, 0.2687831 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5035424], dtype=float32),
#   'logistic': array([0.18189779], dtype=float32),
#   'probabilities': array([0.81810224, 0.18189776], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.06526124], dtype=float32),
#   'logistic': array([0.48369047], dtype=float32),
#   'probabilities': array([0.5163095 , 0.48369044], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0640963], dtype=float32),
#   'logistic': array([0.25652742], dtype=float32),
#   'probabilities': array([0.7434726 , 0.25652742], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6409428], dtype=float32),
#   'logistic': array([0.16233681], dtype=float32),
#   'probabilities': array([0.83766323, 0.16233681], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3535227], dtype=float32),
#   'logistic': array([0.20529506], dtype=float32),
#   'probabilities': array([0.794705  , 0.20529506], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7958109], dtype=float32),
#   'logistic': array([0.14236176], dtype=float32),
#   'probabilities': array([0.85763824, 0.14236176], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3851024], dtype=float32),
#   'logistic': array([0.40489686], dtype=float32),
#   'probabilities': array([0.59510314, 0.40489686], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5097039], dtype=float32),
#   'logistic': array([0.8190173], dtype=float32),
#   'probabilities': array([0.18098266, 0.81901735], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
# ...
#  {'logits': array([0.9500451], dtype=float32),
#   'logistic': array([0.72112423], dtype=float32),
#   'probabilities': array([0.27887574, 0.72112423], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.79269195], dtype=float32),
#   'logistic': array([0.68840903], dtype=float32),
#   'probabilities': array([0.31159097, 0.6884091 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.058322], dtype=float32),
#   'logistic': array([0.7423697], dtype=float32),
#   'probabilities': array([0.25763026, 0.7423697 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.10349202], dtype=float32),
#   'logistic': array([0.52584994], dtype=float32),
#   'probabilities': array([0.47415003, 0.52584994], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6535578], dtype=float32),
#   'logistic': array([0.34218824], dtype=float32),
#   'probabilities': array([0.65781176, 0.34218824], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2994069], dtype=float32),
#   'logistic': array([0.5742975], dtype=float32),
#   'probabilities': array([0.4257025 , 0.57429755], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4285436], dtype=float32),
#   'logistic': array([0.19332573], dtype=float32),
#   'probabilities': array([0.8066743 , 0.19332571], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6144183], dtype=float32),
#   'logistic': array([0.1659761], dtype=float32),
#   'probabilities': array([0.8340239 , 0.16597608], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3301942], dtype=float32),
#   'logistic': array([0.20912725], dtype=float32),
#   'probabilities': array([0.7908728 , 0.20912725], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.23742557], dtype=float32),
#   'logistic': array([0.5590791], dtype=float32),
#   'probabilities': array([0.44092086, 0.5590791 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.5857563], dtype=float32),
#   'logistic': array([0.07006076], dtype=float32),
#   'probabilities': array([0.92993927, 0.07006076], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8179984], dtype=float32),
#   'logistic': array([0.3061887], dtype=float32),
#   'probabilities': array([0.6938113 , 0.30618867], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4729227], dtype=float32),
#   'logistic': array([0.18649879], dtype=float32),
#   'probabilities': array([0.81350124, 0.18649878], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8033401], dtype=float32),
#   'logistic': array([0.30931148], dtype=float32),
#   'probabilities': array([0.6906885 , 0.30931148], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.04214], dtype=float32),
#   'logistic': array([0.2607373], dtype=float32),
#   'probabilities': array([0.73926264, 0.26073724], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.81198984], dtype=float32),
#   'logistic': array([0.30746663], dtype=float32),
#   'probabilities': array([0.6925334 , 0.30746663], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.4724627], dtype=float32),
#   'logistic': array([0.81343144], dtype=float32),
#   'probabilities': array([0.18656859, 0.81343144], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3633922], dtype=float32),
#   'logistic': array([0.20368952], dtype=float32),
#   'probabilities': array([0.7963105 , 0.20368953], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8198445], dtype=float32),
#   'logistic': array([0.13945252], dtype=float32),
#   'probabilities': array([0.8605475 , 0.13945253], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.64186275], dtype=float32),
#   'logistic': array([0.6551744], dtype=float32),
#   'probabilities': array([0.3448256 , 0.65517443], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.16813636], dtype=float32),
#   'logistic': array([0.5419353], dtype=float32),
#   'probabilities': array([0.45806465, 0.5419354 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.8736489], dtype=float32),
#   'logistic': array([0.86687994], dtype=float32),
#   'probabilities': array([0.13312006, 0.86687994], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7258587], dtype=float32),
#   'logistic': array([0.67389584], dtype=float32),
#   'probabilities': array([0.32610416, 0.67389584], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7606249], dtype=float32),
#   'logistic': array([0.1467121], dtype=float32),
#   'probabilities': array([0.853288  , 0.14671211], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.90101564], dtype=float32),
#   'logistic': array([0.71115816], dtype=float32),
#   'probabilities': array([0.2888418, 0.7111582], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.42769468], dtype=float32),
#   'logistic': array([0.605323], dtype=float32),
#   'probabilities': array([0.39467692, 0.605323  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.4748249], dtype=float32),
#   'logistic': array([0.81378967], dtype=float32),
#   'probabilities': array([0.18621035, 0.81378967], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.99629164], dtype=float32),
#   'logistic': array([0.26967114], dtype=float32),
#   'probabilities': array([0.7303288 , 0.26967117], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4016228], dtype=float32),
#   'logistic': array([0.19755873], dtype=float32),
#   'probabilities': array([0.8024413 , 0.19755873], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5208143], dtype=float32),
#   'logistic': array([0.6273382], dtype=float32),
#   'probabilities': array([0.37266183, 0.6273382 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5744773], dtype=float32),
#   'logistic': array([0.17157903], dtype=float32),
#   'probabilities': array([0.828421  , 0.17157903], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5414541], dtype=float32),
#   'logistic': array([0.823676], dtype=float32),
#   'probabilities': array([0.17632397, 0.82367605], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.21044385], dtype=float32),
#   'logistic': array([0.55241764], dtype=float32),
#   'probabilities': array([0.44758233, 0.5524177 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3438177], dtype=float32),
#   'logistic': array([0.20688294], dtype=float32),
#   'probabilities': array([0.7931171 , 0.20688294], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5198016], dtype=float32),
#   'logistic': array([0.62710136], dtype=float32),
#   'probabilities': array([0.37289858, 0.6271014 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.16117883], dtype=float32),
#   'logistic': array([0.5402077], dtype=float32),
#   'probabilities': array([0.45979223, 0.5402077 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9649303], dtype=float32),
#   'logistic': array([0.12293449], dtype=float32),
#   'probabilities': array([0.87706554, 0.12293445], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.40609884], dtype=float32),
#   'logistic': array([0.6001521], dtype=float32),
#   'probabilities': array([0.39984792, 0.6001521 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.65012], dtype=float32),
#   'logistic': array([0.6570375], dtype=float32),
#   'probabilities': array([0.34296247, 0.6570375 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3851244], dtype=float32),
#   'logistic': array([0.7998128], dtype=float32),
#   'probabilities': array([0.20018727, 0.7998128 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.7884519], dtype=float32),
#   'logistic': array([0.8567374], dtype=float32),
#   'probabilities': array([0.14326262, 0.85673743], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.0205518], dtype=float32),
#   'logistic': array([0.49486223], dtype=float32),
#   'probabilities': array([0.5051378 , 0.49486226], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5154092], dtype=float32),
#   'logistic': array([0.18013853], dtype=float32),
#   'probabilities': array([0.81986153, 0.18013851], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1396542], dtype=float32),
#   'logistic': array([0.10530196], dtype=float32),
#   'probabilities': array([0.894698  , 0.10530196], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9546297], dtype=float32),
#   'logistic': array([0.1240494], dtype=float32),
#   'probabilities': array([0.8759506, 0.1240494], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.90944225], dtype=float32),
#   'logistic': array([0.287114], dtype=float32),
#   'probabilities': array([0.712886  , 0.28711393], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4288448], dtype=float32),
#   'logistic': array([0.3944022], dtype=float32),
#   'probabilities': array([0.6055978, 0.3944022], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.92978185], dtype=float32),
#   'logistic': array([0.282969], dtype=float32),
#   'probabilities': array([0.717031  , 0.28296894], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/0y/41vh8h4d1wv2yccr48slhmgc0000gn/T/tmp7q6mbztg
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/0y/41vh8h4d1wv2yccr48slhmgc0000gn/T/tmp7q6mbztg', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a49ae4f60>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-cea30273f6d4> in <module>
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     368
#     369       saving_listeners = _check_listeners_type(saving_listeners)
# --> 370       loss = self._train_model(input_fn, hooks, saving_listeners)
#     371       logging.info('Loss for final step: %s.', loss)
#     372       return self
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1159       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1160     else:
# -> 1161       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1162
#    1163   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1189       worker_hooks.extend(input_hooks)
#    1190       estimator_spec = self._call_model_fn(
# -> 1191           features, labels, ModeKeys.TRAIN, self.config)
#    1192       global_step_tensor = training_util.get_global_step(g)
#    1193       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1147
#    1148     logging.info('Calling model_fn.')
# -> 1149     model_fn_results = self._model_fn(features=features, **kwargs)
#    1150     logging.info('Done calling model_fn.')
#    1151
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     809           input_layer_partitioner=input_layer_partitioner,
#     810           config=config,
# --> 811           batch_norm=batch_norm)
#     812
#     813     super(DNNClassifier, self).__init__(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm)
#     461         input_layer_partitioner=input_layer_partitioner,
#     462         batch_norm=batch_norm)
# --> 463     logits = logit_fn(features=features, mode=mode)
#     464
#     465     return _get_dnn_estimator_spec(use_tpu, head, features, labels, mode,
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in dnn_logit_fn(features, mode)
#     106         input_layer_partitioner,
#     107         batch_norm,
# --> 108         name='dnn')
#     109     return dnn_model(features, mode)
#     110
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/canned/dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, input_layer_partitioner, batch_norm, name, **kwargs)
#     184     if feature_column_lib.is_feature_column_v2(feature_columns):
#     185       self._input_layer = dense_features.DenseFeatures(
# --> 186           feature_columns=feature_columns, name='input_layer')
#     187     else:
#     188       self._input_layer = feature_column.InputLayer(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/feature_column/dense_features.py in __init__(self, feature_columns, trainable, name, **kwargs)
#      84         name=name,
#      85         expected_column_type=fc.DenseColumn,
# ---> 86         **kwargs)
#      87
#      88   @property
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py in __init__(self, feature_columns, expected_column_type, trainable, name, **kwargs)
#     378             'You can wrap a categorical column with an '
#     379             'embedding_column or indicator_column. Given: {}'.format(
# --> 380                 expected_column_type, column))
#     381
#     382   def build(self, _):
#
# ValueError: Items of feature_columns must be a <class 'tensorflow.python.feature_column.feature_column_v2.DenseColumn'>. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)

# %%
dnn_model.train(input_fn=input_func,steps=1000)

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)

# %% [markdown]
# # Great Job!
